# %%
import pandas as pd
import numpy
import math
from matplotlib import pyplot as plt

# %%
databald = []
al = pd.read_csv("experiment_humour_2021-09-23_17-00-54_bald_500_10_1000\humour_overview.csv")
databald.append(al)
al = pd.read_csv("experiment_humour_2021-09-23_18-14-45_bald_500_10_1000\humour_overview.csv")
databald.append(al)
al = pd.read_csv("experiment_humour_2021-09-23_19-43-09_bald_500_10_1000\humour_overview.csv")
databald.append(al)
al = pd.read_csv("experiment_humour_2021-09-23_21-10-17_bald_500_10_1000\humour_overview.csv")
databald.append(al)
al = pd.read_csv("experiment_humour_2021-09-23_22-53-38_bald_500_10_1000\humour_overview.csv")
databald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_00-34-59_bald_500_10_1000\humour_overview.csv")
databald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_02-20-20_bald_500_10_1000\humour_overview.csv")
databald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_03-55-26_bald_500_10_1000\humour_overview.csv")
databald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_05-35-49_bald_500_10_1000\humour_overview.csv")
databald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_07-19-02_bald_500_10_1000\humour_overview.csv")
databald.append(al)

# %%
datamybald = []
al = pd.read_csv("experiment_humour_2021-09-23_21-44-48_mybald_500_10_1000\humour_overview.csv")
datamybald.append(al)
al = pd.read_csv("experiment_humour_2021-09-23_23-21-58_mybald_500_10_1000\humour_overview.csv")
datamybald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_00-58-48_mybald_500_10_1000\humour_overview.csv")
datamybald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_02-33-50_mybald_500_10_1000\humour_overview.csv")
datamybald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_04-23-56_mybald_500_10_1000\humour_overview.csv")
datamybald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_06-04-00_mybald_500_10_1000\humour_overview.csv")
datamybald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_07-37-24_mybald_500_10_1000\humour_overview.csv")
datamybald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_08-57-21_mybald_500_10_1000\humour_overview.csv")
datamybald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_10-12-19_mybald_500_10_1000\humour_overview.csv")
datamybald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_11-30-36_mybald_500_10_1000\humour_overview.csv")
datamybald.append(al)

# %%
datars=[]
rs = al = pd.read_csv("experiment_humour_2021-09-23_18-10-36_random_sample_500_10_1000\humour_overview.csv")
datars.append(al)
rs = al = pd.read_csv("experiment_humour_2021-09-23_19-57-14_random_sample_500_10_1000\humour_overview.csv")
datars.append(al)
rs = al = pd.read_csv("experiment_humour_2021-09-23_21-38-53_random_sample_500_10_1000\humour_overview.csv")
datars.append(al)
rs = al = pd.read_csv("experiment_humour_2021-09-23_23-29-59_random_sample_500_10_1000\humour_overview.csv")
datars.append(al)
rs = al = pd.read_csv("experiment_humour_2021-09-24_01-31-38_random_sample_500_10_1000\humour_overview.csv")
datars.append(al)
rs = al = pd.read_csv("experiment_humour_2021-09-24_03-36-40_random_sample_500_10_1000\humour_overview.csv")
datars.append(al)
rs = al = pd.read_csv("experiment_humour_2021-09-24_05-37-20_random_sample_500_10_1000\humour_overview.csv")
datars.append(al)
rs = al = pd.read_csv("experiment_humour_2021-09-24_07-19-25_random_sample_500_10_1000\humour_overview.csv")
datars.append(al)
rs = al = pd.read_csv("experiment_humour_2021-09-24_09-16-27_random_sample_500_10_1000\humour_overview.csv")
datars.append(al)
rs = al = pd.read_csv("experiment_humour_2021-09-24_10-37-15_random_sample_500_10_1000\humour_overview.csv")
datars.append(al)

# %%
databatchbald = []
al = pd.read_csv("experiment_humour_2021-09-23_23-38-34_batchbald_500_10_1000\humour_overview.csv")
databatchbald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_04-18-07_batchbald_500_10_1000\humour_overview.csv")
databatchbald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_08-32-29_batchbald_500_10_1000\humour_overview.csv")
databatchbald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_11-54-42_batchbald_500_10_1000\humour_overview.csv")
databatchbald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_13-47-34_batchbald_500_10_1000\humour_overview.csv")
databatchbald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_15-20-02_batchbald_500_10_1000\humour_overview.csv")
databatchbald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_16-50-12_batchbald_500_10_1000\humour_overview.csv")
databatchbald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_18-17-28_batchbald_500_10_1000\humour_overview.csv")
databatchbald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_19-49-37_batchbald_500_10_1000\humour_overview.csv")
databatchbald.append(al)
al = pd.read_csv("experiment_humour_2021-09-24_21-23-12_batchbald_500_10_1000\humour_overview.csv")
databatchbald.append(al)

# %%
x = databald[0]["size"].tolist()

# %%
y_rs = []
for rs in datars:
    i = rs["spearman"]
    for j in range(len(i)):
        i[j] = i[j][28:42]
        i[j] = float (i[j])
    i = i.tolist()
    y_rs.append(i)
    
y_rs_mean=[0 for x in range(0,len(y_rs[0]))]
for y in y_rs:
    for j in range(0,len(y)):
        y_rs_mean[j]+=y[j]
for i in range(0,len(y_rs_mean)):
    y_rs_mean[i]/=len(y_rs)

y_rs_sd = [0 for x in range(0,len(y_rs[0]))]
for y in y_rs:
    for j in range(0,len(y)):
        y_rs_sd[j]+= math.pow((y[j]- y_rs_mean[j]),2)
for i in range(0,len(y_rs_mean)):
    y_rs_sd[i] = math.pow((y_rs_sd[i]/len(y_rs)),0.5)
    
y_rs_less = [0 for x in range(0,len(y_rs[0]))]
y_rs_more = [0 for x in range(0,len(y_rs[0]))]
for i in range(len(y_rs_mean)):
    y_rs_less[i] = y_rs_mean[i] - y_rs_sd[i]
    y_rs_more[i] = y_rs_mean[i] + y_rs_sd[i]
# Out:
# C:\Users\www45\AppData\Local\Temp/ipykernel_63008/1098801063.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[j] = i[j][28:42]
# C:\Users\www45\AppData\Local\Temp/ipykernel_63008/1098801063.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[j] = float (i[j])

# %%
y_bald = []
for bald in databald:
    i = bald["spearman"]
    for j in range(len(i)):
        i[j] = i[j][28:42]
        i[j] = float (i[j])
    i = i.tolist()
    y_bald.append(i)
    
y_bald_mean=[0 for x in range(0,len(y_bald[0]))]
for y in y_bald:
    for j in range(0,len(y)):
        y_bald_mean[j]+=y[j]
for i in range(0,len(y_bald_mean)):
    y_bald_mean[i]/=len(y_bald)
y_bald_mean

y_bald_sd = [0 for x in range(0,len(y_bald[0]))]
for y in y_bald:
    for j in range(0,len(y)):
        y_bald_sd[j]+= math.pow((y[j]- y_bald_mean[j]),2)
for i in range(0,len(y_bald_mean)):
    y_bald_sd[i] = math.pow((y_bald_sd[i]/len(y_bald)),0.5)

y_bald_less = [0 for x in range(0,len(y_bald[0]))]
y_bald_more = [0 for x in range(0,len(y_bald[0]))]
for i in range(len(y_bald_mean)):
    y_bald_less[i] = y_bald_mean[i] - y_bald_sd[i]
    y_bald_more[i] = y_bald_mean[i] + y_bald_sd[i]
# Out:
# C:\Users\www45\AppData\Local\Temp/ipykernel_63008/3265579419.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[j] = i[j][28:42]
# C:\Users\www45\AppData\Local\Temp/ipykernel_63008/3265579419.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[j] = float (i[j])

# %%
y_new_bald = []
for bald in datamybald:
    i = bald["spearman"]
    for j in range(len(i)):
        i[j] = i[j][28:42]
        i[j] = float (i[j])
    i = i.tolist()
    y_new_bald.append(i)
    
y_new_bald_mean=[0 for x in range(0,len(y_new_bald[0]))]
for y in y_new_bald:
    for j in range(0,len(y)):
        y_new_bald_mean[j]+=y[j]
for i in range(0,len(y_new_bald_mean)):
    y_new_bald_mean[i]/=len(y_new_bald)
y_new_bald_mean

y_new_bald_sd = [0 for x in range(0,len(y_new_bald[0]))]
for y in y_new_bald:
    for j in range(0,len(y)):
        y_new_bald_sd[j]+= math.pow((y[j]- y_new_bald_mean[j]),2)
for i in range(0,len(y_new_bald_mean)):
    y_new_bald_sd[i] = math.pow((y_new_bald_sd[i]/len(y_new_bald)),0.5)

y_new_bald_less = [0 for x in range(0,len(y_new_bald[0]))]
y_new_bald_more = [0 for x in range(0,len(y_new_bald[0]))]
for i in range(len(y_new_bald_mean)):
    y_new_bald_less[i] = y_new_bald_mean[i] - y_new_bald_sd[i]
    y_new_bald_more[i] = y_new_bald_mean[i] + y_new_bald_sd[i]
# Out:
# C:\Users\www45\AppData\Local\Temp/ipykernel_63008/2348639881.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[j] = i[j][28:42]
# C:\Users\www45\AppData\Local\Temp/ipykernel_63008/2348639881.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[j] = float (i[j])

# %%
y_batch_bald = []
for bald in databatchbald:
    i = bald["spearman"]
    for j in range(len(i)):
        i[j] = i[j][28:42]
        i[j] = float (i[j])
    i = i.tolist()
    y_batch_bald.append(i)
    
y_batch_bald_mean=[0 for x in range(0,len(y_batch_bald[0]))]
for y in y_batch_bald:
    for j in range(0,len(y)):
        y_batch_bald_mean[j]+=y[j]
for i in range(0,len(y_batch_bald_mean)):
    y_batch_bald_mean[i]/=len(y_batch_bald)


y_batch_bald_sd = [0 for x in range(0,len(y_batch_bald[0]))]
for y in y_batch_bald:
    for j in range(0,len(y)):
        y_batch_bald_sd[j]+= math.pow((y[j]- y_batch_bald_mean[j]),2)
for i in range(0,len(y_batch_bald_mean)):
    y_batch_bald_sd[i] = math.pow((y_batch_bald_sd[i]/len(y_batch_bald)),0.5)

y_batch_bald_less = [0 for x in range(0,len(y_batch_bald[0]))]
y_batch_bald_more = [0 for x in range(0,len(y_batch_bald[0]))]
for i in range(len(y_batch_bald_mean)):
    y_batch_bald_less[i] = y_batch_bald_mean[i] - y_batch_bald_sd[i]
    y_batch_bald_more[i] = y_batch_bald_mean[i] + y_batch_bald_sd[i]
# Out:
# C:\Users\www45\AppData\Local\Temp/ipykernel_63008/3086836030.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[j] = i[j][28:42]
# C:\Users\www45\AppData\Local\Temp/ipykernel_63008/3086836030.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i[j] = float (i[j])

# %%
plt.title("") 
plt.xlabel("Acquired data size") 
plt.ylabel("Spearman's rank correlation coefficient") 
# %config InlineBackend.figure_format = 'svg'
#plt.plot(x,y_rs_less,label="Random Sample",color='r' ,alpha=0.1) 
plt.plot(x,y_rs_mean,label="Random Sample",color='r' ) 
#plt.plot(x,y_rs_more,label="Random Sample",color= 'r',alpha=0.1)
plt.fill_between(x, y_rs_less, y_rs_more,
                 facecolor="r", # The fill color
                 color='r',       # The outline color
                 alpha=0.1)          # Transparency of the fill


#plt.plot(x,y_bald_less,label="BALD",color='g' ,alpha=0.1) 
plt.plot(x,y_bald_mean,label="BALD",color='g' ) 
#plt.plot(x,y_bald_more,label="BALD",color= 'g',alpha=0.1)
plt.fill_between(x, y_bald_less, y_bald_more,
                 facecolor="g", # The fill color
                 color='g',       # The outline color
                 alpha=0.1)          # Transparency of the fill

#plt.plot(x,y_bald_less,label="BALD",color='y' ,alpha=0.1) 
plt.plot(x,y_new_bald_mean,label="Replicas Reduced BALD",color='y' ) 
#plt.plot(x,y_bald_more,label="BALD",color= 'y',alpha=0.1)
plt.fill_between(x, y_new_bald_less, y_new_bald_more,
                 facecolor="y", # The fill color
                 color='y',       # The outline color
                 alpha=0.1)          # Transparency of the fill

plt.plot(x,y_batch_bald_mean,label="BatchBALD",color='b' ) 
#plt.plot(x,y_bald_more,label="BALD",color= 'y',alpha=0.1)
plt.fill_between(x, y_batch_bald_less, y_batch_bald_more,
                 facecolor="b", # The fill color
                 color='b',       # The outline color
                 alpha=0.1)          # Transparency of the fill

plt.legend(loc='lower right')

# Show the plot
plt.show()
